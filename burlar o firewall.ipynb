# %% [markdown]
# <a href="https://colab.research.google.com/github/claraa5/claraa5/blob/main/burlar%20o%20firewall.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url_alvo = "http://104.18.140.67"
def testar_conexao(url):
print("Tentando acessar: {url}. . .")

try:
  resposta = request.get(url,timeout=5)
  if resposta.status_code ==200:
    print("[SUCESSO] O site está acessível")
  else:
      print("[AVISO] Recebemos o código: {reposta.status_code}")
except requets.exceptions.ConnectionError:
  print("[BLOQUEIO] Erro de conexão")
except requets.exceptions.Timeout:
  print("[TIMEOUT] A rede demorou muito para uma resposta. Possívelfiltro de pacotes")
except Exception as e:
    print("[ERRO] Ocorreu algo inesperado: {e}")
if __name__ == "__main__":
  testar_conexao(url_alvo)

meus_proxies = {
  "http": "http://ip-do-proxy:porta",
  "https": "http://ip-do-proxy:porta",
}

resposta = requests.get(url, proxies=meus_proxies)
